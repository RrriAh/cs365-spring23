# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
def u ():
    u = np.array([])
    for i in range(10000):
        x = np.random.normal(100, 10)
        y = np.random.normal(300, 10)
        u = np.append(u,x+y)
    plt.hist(u,bins=100)
    

u ()

# %%
def z():
    Z = np.array([])
    for i in range(10000):
        if np.random.rand() < 0.5:
            n =np.random.normal(100, 10)
            Z = np.append(Z,n)
        else:
            n =np.random.normal(300, 10)
            Z = np.append(Z,n)
        
    plt.hist(Z, bins=100)
    plt.show()

z()
